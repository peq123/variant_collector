# %%
import variant_collector as vc
import pandas as pd

# %%
BRCA1 =  vc.gene(ensembl_id="ENSG00000012048")
BRCA1.get_identification() # load in the gene identification from other sources using HGNC

df = BRCA1.load_transcripts()
# Out:
# Some of the identifying information has not been provided, use .get_identification() to retrieve full identification from HGNC API

# %%
# use biomart to download list of gene id from ensembl

listofensemblid = ["ENSG00000012048"]

for id in listofensemblid:
    thisgene = vc.gene(ensembl_id=id)
    thisgene.get_identification()

    df = thisgene.load_transcripts()


    canoncial = df[df["entrez_canonical"] == True] # should only bring back one transcript
    transcriptid = canoncial.iloc[0]["entrez_accessionversion"]
    listofexons = canoncial.iloc[0]["entrez_exons"]# this is a list
    
    for exon in listofexons:
        #positions = exon['Genomic_Interval_Exon'].split("-")
        #if positions[0] > positions[1]:
        #    # reverse strand
        #    pass
        #else:
        #    # forward strand
        #    pass
        print(transcriptid,exon)
# Out:
# Some of the identifying information has not been provided, use .get_identification() to retrieve full identification from HGNC API
# NM_007294.4 {'Genomic_Interval_Exon': '43125364-43125271', 'Genomic_Interval_Coding': '', 'Gene_Interval_Exon': '1-94', 'Gene_Interval_Coding': '', 'Exon_Length': '', 'Coding_Length': '', 'Intron_Length': ''}
# NM_007294.4 {'Genomic_Interval_Exon': '43124115-43124017', 'Genomic_Interval_Coding': '43124096-43124017', 'Gene_Interval_Exon': '1250-1348', 'Gene_Interval_Coding': '1269-1348', 'Exon_Length': '99', 'Coding_Length': '80', 'Intron_Length': '8237'}
# NM_007294.4 {'Genomic_Interval_Exon': '43115779-43115726', 'Genomic_Interval_Coding': '43115779-43115726', 'Gene_Interval_Exon': '9586-9639', 'Gene_Interval_Coding': '9586-9639', 'Exon_Length': '54', 'Coding_Length': '54', 'Intron_Length': '9192'}
# NM_007294.4 {'Genomic_Interval_Exon': '43106533-43106456', 'Genomic_Interval_Coding': '43106533-43106456', 'Gene_Interval_Exon': '18832-18909', 'Gene_Interval_Coding': '18832-18909', 'Exon_Length': '78', 'Coding_Length': '78', 'Intron_Length': '1499'}
# NM_007294.4 {'Genomic_Interval_Exon': '43104956-43104868', 'Genomic_Interval_Coding': '43104956-43104868', 'Gene_Interval_Exon': '20409-20497', 'Gene_Interval_Coding': '20409-20497', 'Exon_Length': '89', 'Coding_Length': '89', 'Intron_Length': '606'}
# NM_007294.4 {'Genomic_Interval_Exon': '43104261-43104122', 'Genomic_Interval_Coding': '43104261-43104122', 'Gene_Interval_Exon': '21104-21243', 'Gene_Interval_Coding': '21104-21243', 'Exon_Length': '140', 'Coding_Length': '140', 'Intron_Length': '4241'}
# NM_007294.4 {'Genomic_Interval_Exon': '43099880-43099775', 'Genomic_Interval_Coding': '43099880-43099775', 'Gene_Interval_Exon': '25485-25590', 'Gene_Interval_Coding': '25485-25590', 'Exon_Length': '106', 'Coding_Length': '106', 'Intron_Length': '2485'}
# NM_007294.4 {'Genomic_Interval_Exon': '43097289-43097244', 'Genomic_Interval_Coding': '43097289-43097244', 'Gene_Interval_Exon': '28076-28121', 'Gene_Interval_Coding': '28076-28121', 'Exon_Length': '46', 'Coding_Length': '46', 'Intron_Length': '1321'}
# NM_007294.4 {'Genomic_Interval_Exon': '43095922-43095846', 'Genomic_Interval_Coding': '43095922-43095846', 'Gene_Interval_Exon': '29443-29519', 'Gene_Interval_Coding': '29443-29519', 'Exon_Length': '77', 'Coding_Length': '77', 'Intron_Length': '985'}
# NM_007294.4 {'Genomic_Interval_Exon': '43094860-43091435', 'Genomic_Interval_Coding': '43094860-43091435', 'Gene_Interval_Exon': '30505-33930', 'Gene_Interval_Coding': '30505-33930', 'Exon_Length': '3426', 'Coding_Length': '3426', 'Intron_Length': '402'}
# NM_007294.4 {'Genomic_Interval_Exon': '43091032-43090944', 'Genomic_Interval_Coding': '43091032-43090944', 'Gene_Interval_Exon': '34333-34421', 'Gene_Interval_Coding': '34333-34421', 'Exon_Length': '89', 'Coding_Length': '89', 'Intron_Length': '8368'}
# NM_007294.4 {'Genomic_Interval_Exon': '43082575-43082404', 'Genomic_Interval_Coding': '43082575-43082404', 'Gene_Interval_Exon': '42790-42961', 'Gene_Interval_Coding': '42790-42961', 'Exon_Length': '172', 'Coding_Length': '172', 'Intron_Length': '5789'}
# NM_007294.4 {'Genomic_Interval_Exon': '43076614-43076488', 'Genomic_Interval_Coding': '43076614-43076488', 'Gene_Interval_Exon': '48751-48877', 'Gene_Interval_Coding': '48751-48877', 'Exon_Length': '127', 'Coding_Length': '127', 'Intron_Length': '1966'}
# NM_007294.4 {'Genomic_Interval_Exon': '43074521-43074331', 'Genomic_Interval_Coding': '43074521-43074331', 'Gene_Interval_Exon': '50844-51034', 'Gene_Interval_Coding': '50844-51034', 'Exon_Length': '191', 'Coding_Length': '191', 'Intron_Length': '3092'}
# NM_007294.4 {'Genomic_Interval_Exon': '43071238-43070928', 'Genomic_Interval_Coding': '43071238-43070928', 'Gene_Interval_Exon': '54127-54437', 'Gene_Interval_Coding': '54127-54437', 'Exon_Length': '311', 'Coding_Length': '311', 'Intron_Length': '3232'}
# NM_007294.4 {'Genomic_Interval_Exon': '43067695-43067608', 'Genomic_Interval_Coding': '43067695-43067608', 'Gene_Interval_Exon': '57670-57757', 'Gene_Interval_Coding': '57670-57757', 'Exon_Length': '88', 'Coding_Length': '88', 'Intron_Length': '3656'}
# NM_007294.4 {'Genomic_Interval_Exon': '43063951-43063874', 'Genomic_Interval_Coding': '43063951-43063874', 'Gene_Interval_Exon': '61414-61491', 'Gene_Interval_Coding': '61414-61491', 'Exon_Length': '78', 'Coding_Length': '78', 'Intron_Length': '500'}
# NM_007294.4 {'Genomic_Interval_Exon': '43063373-43063333', 'Genomic_Interval_Coding': '43063373-43063333', 'Gene_Interval_Exon': '61992-62032', 'Gene_Interval_Coding': '61992-62032', 'Exon_Length': '41', 'Coding_Length': '41', 'Intron_Length': '6197'}
# NM_007294.4 {'Genomic_Interval_Exon': '43057135-43057052', 'Genomic_Interval_Coding': '43057135-43057052', 'Gene_Interval_Exon': '68230-68313', 'Gene_Interval_Coding': '68230-68313', 'Exon_Length': '84', 'Coding_Length': '84', 'Intron_Length': '5934'}
# NM_007294.4 {'Genomic_Interval_Exon': '43051117-43051063', 'Genomic_Interval_Coding': '43051117-43051063', 'Gene_Interval_Exon': '74248-74302', 'Gene_Interval_Coding': '74248-74302', 'Exon_Length': '55', 'Coding_Length': '55', 'Intron_Length': '1868'}
# NM_007294.4 {'Genomic_Interval_Exon': '43049194-43049121', 'Genomic_Interval_Coding': '43049194-43049121', 'Gene_Interval_Exon': '76171-76244', 'Gene_Interval_Coding': '76171-76244', 'Exon_Length': '74', 'Coding_Length': '74', 'Intron_Length': '1417'}
# NM_007294.4 {'Genomic_Interval_Exon': '43047703-43047643', 'Genomic_Interval_Coding': '43047703-43047643', 'Gene_Interval_Exon': '77662-77722', 'Gene_Interval_Coding': '77662-77722', 'Exon_Length': '61', 'Coding_Length': '61', 'Intron_Length': '1840'}
# NM_007294.4 {'Genomic_Interval_Exon': '43045802-43044295', 'Genomic_Interval_Coding': '43045802-43045678', 'Gene_Interval_Exon': '79563-81070', 'Gene_Interval_Coding': '79563-79687', 'Exon_Length': '1508', 'Coding_Length': '125', 'Intron_Length': ''}

# %%
df
# Out:
#    ensembl_feature_type ensembl_assembly_name  ensembl_end  \
# 0            transcript                GRCh38   43125370.0
# 1            transcript                GRCh38   43091851.0
# 2            transcript                GRCh38   43125329.0
# 3            transcript                GRCh38   43125329.0
# 4            transcript                GRCh38   43125329.0
# 5            transcript                GRCh38   43125288.0
# 6            transcript                GRCh38   43104916.0
# 7            transcript                GRCh38   43125359.0
# 8            transcript                GRCh38   43125402.0
# 9            transcript                GRCh38   43071066.0
# 10           transcript                GRCh38   43082760.0
# 11           transcript                GRCh38   43104916.0
# 12           transcript                GRCh38   43091824.0
# 13           transcript                GRCh38   43125315.0
# 14           transcript                GRCh38   43170245.0
# 15           transcript                GRCh38   43095866.0
# 16           transcript                GRCh38   43125323.0
# 17           transcript                GRCh38   43125483.0
# 18           transcript                GRCh38   43125364.0
# 19           transcript                GRCh38   43125300.0
# 20           transcript                GRCh38   43125300.0
# 21           transcript                GRCh38   43125450.0
# 22           transcript                GRCh38   43104891.0
# 23           transcript                GRCh38   43125343.0
# 24           transcript                GRCh38   43125353.0
# 25           transcript                GRCh38   43125370.0
# 26           transcript                GRCh38   43125321.0
# 27           transcript                GRCh38   43125326.0
# 28           transcript                GRCh38   43125364.0
# 29           transcript                GRCh38   43125364.0
# 30           transcript                GRCh38   43125483.0
# 31           transcript                GRCh38   43125451.0
# 32           transcript                GRCh38   43125402.0
# 33           transcript                GRCh38   43125356.0
# 34                  NaN                   NaN          NaN
#
#    ensembl_external_name                      ensembl_logic_name  \
# 0              BRCA1-201                     havana_homo_sapiens
# 1              BRCA1-232                     havana_homo_sapiens
# 2              BRCA1-225  ensembl_havana_transcript_homo_sapiens
# 3              BRCA1-226  ensembl_havana_transcript_homo_sapiens
# 4              BRCA1-227                     havana_homo_sapiens
# 5              BRCA1-205                     havana_homo_sapiens
# 6              BRCA1-216                     havana_homo_sapiens
# 7              BRCA1-215                     havana_homo_sapiens
# 8              BRCA1-222                     havana_homo_sapiens
# 9              BRCA1-211                     havana_homo_sapiens
# 10             BRCA1-229                     havana_homo_sapiens
# 11             BRCA1-217                     havana_homo_sapiens
# 12             BRCA1-206                     havana_homo_sapiens
# 13             BRCA1-202                     havana_homo_sapiens
# 14             BRCA1-230                     havana_homo_sapiens
# 15             BRCA1-204                     havana_homo_sapiens
# 16             BRCA1-209                     havana_homo_sapiens
# 17             BRCA1-234                     havana_homo_sapiens
# 18             BRCA1-214                     havana_homo_sapiens
# 19             BRCA1-220                     havana_homo_sapiens
# 20             BRCA1-224                     havana_homo_sapiens
# 21             BRCA1-223                     havana_homo_sapiens
# 22             BRCA1-212                     havana_homo_sapiens
# 23             BRCA1-231                     havana_homo_sapiens
# 24             BRCA1-213                     havana_homo_sapiens
# 25             BRCA1-207                     havana_homo_sapiens
# 26             BRCA1-218                     havana_homo_sapiens
# 27             BRCA1-233                     havana_homo_sapiens
# 28             BRCA1-228                     havana_homo_sapiens
# 29             BRCA1-203  ensembl_havana_transcript_homo_sapiens
# 30             BRCA1-210  ensembl_havana_transcript_homo_sapiens
# 31             BRCA1-208  ensembl_havana_transcript_homo_sapiens
# 32             BRCA1-221  ensembl_havana_transcript_homo_sapiens
# 33             BRCA1-219                     havana_homo_sapiens
# 34                   NaN                                     NaN
#
#    ensembl_description   ensembl_Parent    ensembl_transcript_support_level  \
# 0                 None  ENSG00000012048                                   5
# 1                 None  ENSG00000012048                                 NaN
# 2                 None  ENSG00000012048                                   1
# 3                 None  ENSG00000012048                                   1
# 4                 None  ENSG00000012048                                   1
# 5                 None  ENSG00000012048                                   1
# 6                 None  ENSG00000012048                                   5
# 7                 None  ENSG00000012048                                   1
# 8                 None  ENSG00000012048                                   2
# 9                 None  ENSG00000012048                                   3
# 10                None  ENSG00000012048                                   5
# 11                None  ENSG00000012048                                   5
# 12                None  ENSG00000012048                                   2
# 13                None  ENSG00000012048                                   1
# 14                None  ENSG00000012048                                   5
# 15                None  ENSG00000012048                                   1
# 16                None  ENSG00000012048                                   1
# 17                None  ENSG00000012048                                 NaN
# 18                None  ENSG00000012048                                   1
# 19                None  ENSG00000012048                                   1
# 20                None  ENSG00000012048                                   1
# 21                None  ENSG00000012048                                   1
# 22                None  ENSG00000012048                                   2
# 23                None  ENSG00000012048                                 NaN
# 24                None  ENSG00000012048                                   5
# 25                None  ENSG00000012048                                   3
# 26                None  ENSG00000012048                                   4
# 27                None  ENSG00000012048                                 NaN
# 28                None  ENSG00000012048                                   1
# 29                None  ENSG00000012048  1 (assigned to previous version 7)
# 30                None  ENSG00000012048  1 (assigned to previous version 6)
# 31                None  ENSG00000012048                                   1
# 32                None  ENSG00000012048                                   5
# 33                None  ENSG00000012048                                   5
# 34                 NaN              NaN                                 NaN
#
#    ensembl_transcript_id          ensembl_biotype  ...  entrez_biosample  \
# 0        ENST00000352993           protein_coding  ...               NaN
# 1        ENST00000644379           protein_coding  ...               NaN
# 2        ENST00000586385           protein_coding  ...               NaN
# 3        ENST00000591534           protein_coding  ...               NaN
# 4        ENST00000591849           protein_coding  ...               NaN
# 5        ENST00000461221  nonsense_mediated_decay  ...               NaN
# 6        ENST00000484087           protein_coding  ...               NaN
# 7        ENST00000478531           protein_coding  ...               NaN
# 8        ENST00000493919           protein_coding  ...               NaN
# 9        ENST00000472490          retained_intron  ...               NaN
# 10       ENST00000621897     processed_transcript  ...               NaN
# 11       ENST00000487825           protein_coding  ...               NaN
# 12       ENST00000461574           protein_coding  ...               NaN
# 13       ENST00000354071           protein_coding  ...               NaN
# 14       ENST00000634433           protein_coding  ...               NaN
# 15       ENST00000412061           non_stop_decay  ...               NaN
# 16       ENST00000470026           protein_coding  ...               NaN
# 17       ENST00000652672           protein_coding  ...               NaN
# 18       ENST00000477152           protein_coding  ...               NaN
# 19       ENST00000492859  nonsense_mediated_decay  ...               NaN
# 20       ENST00000497488           protein_coding  ...               NaN
# 21       ENST00000494123           protein_coding  ...               NaN
# 22       ENST00000473961           protein_coding  ...               NaN
# 23       ENST00000642945  nonsense_mediated_decay  ...               NaN
# 24       ENST00000476777           protein_coding  ...               NaN
# 25       ENST00000461798  nonsense_mediated_decay  ...               NaN
# 26       ENST00000489037           protein_coding  ...               NaN
# 27       ENST00000644555           protein_coding  ...               NaN
# 28       ENST00000618469           protein_coding  ...               NaN
# 29       ENST00000357654           protein_coding  ...
# 30       ENST00000471181           protein_coding  ...
# 31       ENST00000468300           protein_coding  ...
# 32       ENST00000493795           protein_coding  ...
# 33       ENST00000491747           protein_coding  ...
# 34                   NaN                      NaN  ...
#
#                                     entrez_statistics  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  [{'type': 'Length', 'count': 7088}, {'type': '...
# 30  [{'type': 'Length', 'count': 7151}, {'type': '...
# 31  [{'type': 'Length', 'count': 3696}, {'type': '...
# 32  [{'type': 'Length', 'count': 7028}, {'type': '...
# 33  [{'type': 'Length', 'count': 3699}, {'type': '...
# 34  [{'type': 'Length', 'count': 7152}, {'type': '...
#
#             entrez_properties                                entrez_oslt  \
# 0                         NaN                                        NaN
# 1                         NaN                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4                         NaN                                        NaN
# 5                         NaN                                        NaN
# 6                         NaN                                        NaN
# 7                         NaN                                        NaN
# 8                         NaN                                        NaN
# 9                         NaN                                        NaN
# 10                        NaN                                        NaN
# 11                        NaN                                        NaN
# 12                        NaN                                        NaN
# 13                        NaN                                        NaN
# 14                        NaN                                        NaN
# 15                        NaN                                        NaN
# 16                        NaN                                        NaN
# 17                        NaN                                        NaN
# 18                        NaN                                        NaN
# 19                        NaN                                        NaN
# 20                        NaN                                        NaN
# 21                        NaN                                        NaN
# 22                        NaN                                        NaN
# 23                        NaN                                        NaN
# 24                        NaN                                        NaN
# 25                        NaN                                        NaN
# 26                        NaN                                        NaN
# 27                        NaN                                        NaN
# 28                        NaN                                        NaN
# 29  {'na': '1', 'value': '1'}  {'indexed': True, 'value': 'NM_007294.4'}
# 30  {'na': '1', 'value': '1'}  {'indexed': True, 'value': 'NM_007300.4'}
# 31  {'na': '1', 'value': '1'}  {'indexed': True, 'value': 'NM_007299.4'}
# 32  {'na': '1', 'value': '1'}  {'indexed': True, 'value': 'NM_007297.4'}
# 33  {'na': '1', 'value': '1'}  {'indexed': True, 'value': 'NM_007298.3'}
# 34  {'na': '1', 'value': '1'}  {'indexed': True, 'value': 'NR_027676.2'}
#
#    entrez_accessionversion  entrez_canonical entrez_ccdsid  \
# 0                      NaN               NaN           NaN
# 1                      NaN               NaN           NaN
# 2                      NaN               NaN           NaN
# 3                      NaN               NaN           NaN
# 4                      NaN               NaN           NaN
# 5                      NaN               NaN           NaN
# 6                      NaN               NaN           NaN
# 7                      NaN               NaN           NaN
# 8                      NaN               NaN           NaN
# 9                      NaN               NaN           NaN
# 10                     NaN               NaN           NaN
# 11                     NaN               NaN           NaN
# 12                     NaN               NaN           NaN
# 13                     NaN               NaN           NaN
# 14                     NaN               NaN           NaN
# 15                     NaN               NaN           NaN
# 16                     NaN               NaN           NaN
# 17                     NaN               NaN           NaN
# 18                     NaN               NaN           NaN
# 19                     NaN               NaN           NaN
# 20                     NaN               NaN           NaN
# 21                     NaN               NaN           NaN
# 22                     NaN               NaN           NaN
# 23                     NaN               NaN           NaN
# 24                     NaN               NaN           NaN
# 25                     NaN               NaN           NaN
# 26                     NaN               NaN           NaN
# 27                     NaN               NaN           NaN
# 28                     NaN               NaN           NaN
# 29             NM_007294.4              True   CCDS11453.1
# 30             NM_007300.4             False   CCDS11456.2
# 31             NM_007299.4             False   CCDS11455.2
# 32             NM_007297.4             False   CCDS11459.2
# 33             NM_007298.3             False   CCDS11454.2
# 34             NR_027676.2             False
#
#                                          entrez_exons entrez_start entrez_end
# 0                                                 NaN          NaN        NaN
# 1                                                 NaN          NaN        NaN
# 2                                                 NaN          NaN        NaN
# 3                                                 NaN          NaN        NaN
# 4                                                 NaN          NaN        NaN
# 5                                                 NaN          NaN        NaN
# 6                                                 NaN          NaN        NaN
# 7                                                 NaN          NaN        NaN
# 8                                                 NaN          NaN        NaN
# 9                                                 NaN          NaN        NaN
# 10                                                NaN          NaN        NaN
# 11                                                NaN          NaN        NaN
# 12                                                NaN          NaN        NaN
# 13                                                NaN          NaN        NaN
# 14                                                NaN          NaN        NaN
# 15                                                NaN          NaN        NaN
# 16                                                NaN          NaN        NaN
# 17                                                NaN          NaN        NaN
# 18                                                NaN          NaN        NaN
# 19                                                NaN          NaN        NaN
# 20                                                NaN          NaN        NaN
# 21                                                NaN          NaN        NaN
# 22                                                NaN          NaN        NaN
# 23                                                NaN          NaN        NaN
# 24                                                NaN          NaN        NaN
# 25                                                NaN          NaN        NaN
# 26                                                NaN          NaN        NaN
# 27                                                NaN          NaN        NaN
# 28                                                NaN          NaN        NaN
# 29  [{'Genomic_Interval_Exon': '43125364-43125271'...          0.0        0.0
# 30  [{'Genomic_Interval_Exon': '43125364-43125271'...          0.0        0.0
# 31  [{'Genomic_Interval_Exon': '43125364-43125277'...          0.0        0.0
# 32  [{'Genomic_Interval_Exon': '43125364-43125277'...          0.0        0.0
# 33  [{'Genomic_Interval_Exon': '43124115-43124017'...          0.0        0.0
# 34  [{'Genomic_Interval_Exon': '43125364-43125182'...          0.0        0.0
#
# [35 rows x 55 columns]

# %%
# Out:
# 43125364-43125271
# 43124115-43124017
# 43115779-43115726
# 43106533-43106456
# 43104956-43104868
# 43104261-43104122
# 43099880-43099775
# 43097289-43097244
# 43095922-43095846
# 43094860-43091435
# 43091032-43090944
# 43082575-43082404
# 43076614-43076488
# 43074521-43074331
# 43071238-43070928
# 43067695-43067608
# 43063951-43063874
# 43063373-43063333
# 43057135-43057052
# 43051117-43051063
# 43049194-43049121
# 43047703-43047643
# 43045802-43044295
